# %%
# !pip install google-cloud-bigquery pandas

from google.cloud import bigquery

client = bigquery.Client()

# Query Yelp data directly from BigQuery (no download needed)
query = """
    SELECT * FROM `bigquery-public-data.yelp.business` LIMIT 100
"""
df = client.query(query).to_pandas()
print(df.head())
# Out:
# ...
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/credentials.py in _perform_refresh_token(self, request)
#     138         try:
# --> 139             self._retrieve_info(request)
#     140             scopes = self._scopes if self._scopes is not None else self._default_scopes
#
# /usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/credentials.py in _retrieve_info(self, request)
#     106         """
# --> 107         info = _metadata.get_service_account_info(
#     108             request, service_account=self._service_account_email
#
# /usr/local/lib/python3.12/dist-packages/google/auth/compute_engine/_metadata.py in get_service_account_info(request, service_account)
#     442     # for more on the use of 'recursive'.
# --> 443     return get(request, path, params={"recursive": "true"})
#     444
# ...
